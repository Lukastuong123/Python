# %%
#load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
# Out:
# C:\Users\Shivam\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#load datasets
unemp_df = pd.read_csv("Bureau_of_Labor_Statistics_Monthly_Unemployment__current_14_months_.csv")
cvi_df = pd.read_csv("Chmura_CVI_Counties_April_2020.csv")
glob_mob = pd.read_csv("Global_Mobility_Report.csv")
# Out:
# C:\Users\Shivam\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#check umemployment data
unemp_df.head()
# Out:
#    FID  COUNTYNS  GEOID       ALAND      AWATER            NAME    State  \
# 0    1    161526   1001  1539602137    25706961  Autauga County  Alabama
# 1    2    161527   1003  4117621645  1132980868  Baldwin County  Alabama
# 2    3    161528   1005  2292160139    50523213  Barbour County  Alabama
# 3    4    161529   1007  1612167476     9602089     Bibb County  Alabama
# 4    5    161530   1009  1670103866    15015467   Blount County  Alabama
#
#    fips  LaborForce_CurrentMonth  LaborForce_01Month  ...        P06Month  \
# 0  1001                  25557.0               25906  ...  September 2019
# 1  1003                  95672.0               95924  ...  September 2019
# 2  1005                   8434.0                8532  ...  September 2019
# 3  1007                   8524.0                8628  ...  September 2019
# 4  1009                  24820.0               25179  ...  September 2019
#
#       P07Month   P08Month   P09Month  P10Month    P11Month    P12Month  \
# 0  August 2019  July 2019  June 2019  May 2019  April 2019  March 2019
# 1  August 2019  July 2019  June 2019  May 2019  April 2019  March 2019
# 2  August 2019  July 2019  June 2019  May 2019  April 2019  March 2019
# 3  August 2019  July 2019  June 2019  May 2019  April 2019  March 2019
# 4  August 2019  July 2019  June 2019  May 2019  April 2019  March 2019
#
#         P13Month  SHAPE_Length  SHAPE_Area
# 0  February 2019      2.066037    0.150256
# 1  February 2019      4.483746    0.409904
# 2  February 2019      2.695262    0.223270
# 3  February 2019      1.887514    0.156473
# 4  February 2019      2.423552    0.164405
#
# [5 rows x 80 columns]

# %%
pd.options.display.max_rows = 80


#check for the missing data
unemp_df.isna().sum()
# Out:
# FID                      0
# COUNTYNS                 0
# GEOID                    0
# ALAND                    0
# AWATER                   0
# NAME                     0
# State                    0
# fips                     0
# LaborForce_01Month       0
# LaborForce_02Month       0
# LaborForce_03Month       0
# LaborForce_04Month       0
# LaborForce_05Month       0
# LaborForce_06Month       0
# LaborForce_07Month       0
# LaborForce_08Month       0
# LaborForce_09Month       0
# LaborForce_10Month       0
# LaborForce_11Month       0
# LaborForce_12Month       0
# LaborForce_13Month       0
# Employed_01Month         0
# Employed_02Month         0
# Employed_03Month         0
# Employed_04Month         0
# Employed_05Month         0
# Employed_06Month         0
# Employed_07Month         0
# Employed_08Month         0
# Employed_09Month         0
# Employed_10Month         0
# Employed_11Month         0
# Employed_12Month         0
# Employed_13Month         0
# Unemployed_01Month       0
# Unemployed_02Month       0
# Unemployed_03Month       0
# Unemployed_04Month       0
# Unemployed_05Month       0
# Unemployed_06Month       0
# Unemployed_07Month       0
# Unemployed_08Month       0
# Unemployed_09Month       0
# Unemployed_10Month       0
# Unemployed_11Month       0
# Unemployed_12Month       0
# Unemployed_13Month       0
# PctUnemployed_01Month    0
# PctUnemployed_02Month    0
# PctUnemployed_03Month    0
# PctUnemployed_04Month    0
# PctUnemployed_05Month    0
# PctUnemployed_06Month    0
# PctUnemployed_07Month    0
# PctUnemployed_08Month    0
# PctUnemployed_09Month    0
# PctUnemployed_10Month    0
# PctUnemployed_11Month    0
# PctUnemployed_12Month    0
# PctUnemployed_13Month    0
# CurrentMonth             0
# P01Month                 0
# P02Month                 0
# P03Month                 0
# P04Month                 0
# P05Month                 0
# P06Month                 0
# P07Month                 0
# P08Month                 0
# P09Month                 0
# P10Month                 0
# P11Month                 0
# P12Month                 0
# P13Month                 0
# SHAPE_Length             0
# SHAPE_Area               0
# dtype: int64

# %%
#drop the columns 
unemp_df.dropna(axis=1,inplace=True)

# %%
#check for the duplicates
unemp_df.duplicated().sum()
# Out:
# 0

# %%
unemp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3219 entries, 0 to 3218
# Data columns (total 76 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FID                    3219 non-null   int64
#  1   COUNTYNS               3219 non-null   int64
#  2   GEOID                  3219 non-null   int64
#  3   ALAND                  3219 non-null   int64
#  4   AWATER                 3219 non-null   int64
#  5   NAME                   3219 non-null   object
#  6   State                  3219 non-null   object
#  7   fips                   3219 non-null   int64
#  8   LaborForce_01Month     3219 non-null   int64
#  9   LaborForce_02Month     3219 non-null   int64
#  10  LaborForce_03Month     3219 non-null   int64
#  11  LaborForce_04Month     3219 non-null   int64
#  12  LaborForce_05Month     3219 non-null   int64
#  13  LaborForce_06Month     3219 non-null   int64
#  14  LaborForce_07Month     3219 non-null   int64
#  15  LaborForce_08Month     3219 non-null   int64
#  16  LaborForce_09Month     3219 non-null   int64
#  17  LaborForce_10Month     3219 non-null   int64
#  18  LaborForce_11Month     3219 non-null   int64
#  19  LaborForce_12Month     3219 non-null   int64
#  20  LaborForce_13Month     3219 non-null   int64
#  21  Employed_01Month       3219 non-null   int64
#  22  Employed_02Month       3219 non-null   int64
#  23  Employed_03Month       3219 non-null   int64
#  24  Employed_04Month       3219 non-null   int64
#  25  Employed_05Month       3219 non-null   int64
#  26  Employed_06Month       3219 non-null   int64
#  27  Employed_07Month       3219 non-null   int64
#  28  Employed_08Month       3219 non-null   int64
#  29  Employed_09Month       3219 non-null   int64
#  30  Employed_10Month       3219 non-null   int64
#  31  Employed_11Month       3219 non-null   int64
#  32  Employed_12Month       3219 non-null   int64
#  33  Employed_13Month       3219 non-null   int64
#  34  Unemployed_01Month     3219 non-null   int64
#  35  Unemployed_02Month     3219 non-null   int64
#  36  Unemployed_03Month     3219 non-null   int64
#  37  Unemployed_04Month     3219 non-null   int64
#  38  Unemployed_05Month     3219 non-null   int64
#  39  Unemployed_06Month     3219 non-null   int64
#  40  Unemployed_07Month     3219 non-null   int64
#  41  Unemployed_08Month     3219 non-null   int64
#  42  Unemployed_09Month     3219 non-null   int64
#  43  Unemployed_10Month     3219 non-null   int64
#  44  Unemployed_11Month     3219 non-null   int64
#  45  Unemployed_12Month     3219 non-null   int64
#  46  Unemployed_13Month     3219 non-null   int64
#  47  PctUnemployed_01Month  3219 non-null   float64
#  48  PctUnemployed_02Month  3219 non-null   float64
#  49  PctUnemployed_03Month  3219 non-null   float64
#  50  PctUnemployed_04Month  3219 non-null   float64
#  51  PctUnemployed_05Month  3219 non-null   float64
#  52  PctUnemployed_06Month  3219 non-null   float64
#  53  PctUnemployed_07Month  3219 non-null   float64
#  54  PctUnemployed_08Month  3219 non-null   float64
#  55  PctUnemployed_09Month  3219 non-null   float64
#  56  PctUnemployed_10Month  3219 non-null   float64
#  57  PctUnemployed_11Month  3219 non-null   float64
#  58  PctUnemployed_12Month  3219 non-null   float64
#  59  PctUnemployed_13Month  3219 non-null   float64
#  60  CurrentMonth           3219 non-null   object
#  61  P01Month               3219 non-null   object
#  62  P02Month               3219 non-null   object
#  63  P03Month               3219 non-null   object
#  64  P04Month               3219 non-null   object
#  65  P05Month               3219 non-null   object
#  66  P06Month               3219 non-null   object
#  67  P07Month               3219 non-null   object
#  68  P08Month               3219 non-null   object
#  69  P09Month               3219 non-null   object
#  70  P10Month               3219 non-null   object
#  71  P11Month               3219 non-null   object
#  72  P12Month               3219 non-null   object
#  73  P13Month               3219 non-null   object
#  74  SHAPE_Length           3219 non-null   float64
#  75  SHAPE_Area             3219 non-null   float64
# dtypes: float64(15), int64(45), object(16)
# memory usage: 1.9+ MB

# %%
unemp_df_1 = unemp_df.iloc[:,[3,4,5,6,7,8,9,21,34,47,60]]

# %%
#check cvi data
cvi_df.head()
# Out:
#                  f2       f3      f4    f5  objectId  \
# 0        Lee County  Alabama  119.27   263         2
# 1  Limestone County  Alabama   86.90  1504         3
# 2    Lowndes County  Alabama   62.09  2672         4
# 3      Macon County  Alabama   77.36  2029         5
# 4    Madison County  Alabama   92.55  1191         6
#
#                                EXCEL_ID  FIPS
# 0  5062f63e-56f7-4fad-8c2c-59a5511a4a64  1081
# 1  3a26d5ec-95fd-44d8-bd09-a0fa78c67ae4  1083
# 2  a3f9056b-9636-42cb-8fa2-898110a184ac  1085
# 3  9faf7c64-738c-4f8a-995c-4f371fedb1ac  1087
# 4  def16b20-a759-4b14-acc1-4260073e04b0  1089

# %%
#change the col names of cvi data
cvi_colnames = ['county_cvi','state_cvi','vulnerability_index','rank_cvi','objected_cvi','excel_id_cvi','fips_cvi']

cvi_df.columns = cvi_colnames

# %%
#test the column names
cvi_df.head(1)
# Out:
#    county_cvi state_cvi  vulnerability_index  rank_cvi  objected_cvi  \
# 0  Lee County   Alabama               119.27       263             2
#
#                            excel_id_cvi  fips_cvi
# 0  5062f63e-56f7-4fad-8c2c-59a5511a4a64      1081

# %%
#check for missing data
cvi_df.isna().sum()
# Out:
# county_cvi             0
# state_cvi              0
# vulnerability_index    0
# rank_cvi               0
# objected_cvi           0
# excel_id_cvi           0
# fips_cvi               0
# dtype: int64

# %%
#check for duplicates
cvi_df.duplicated().sum()
# Out:
# 0

# %%
#check info
cvi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   county_cvi           3141 non-null   object
#  1   state_cvi            3141 non-null   object
#  2   vulnerability_index  3141 non-null   float64
#  3   rank_cvi             3141 non-null   int64
#  4   objected_cvi         3141 non-null   int64
#  5   excel_id_cvi         3141 non-null   object
#  6   fips_cvi             3141 non-null   int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 171.9+ KB

# %% [markdown]
# ## Combine both the data

# %%
#merge on county ans state
df = pd.merge(unemp_df_1,cvi_df,left_on=['NAME','State'],right_on=['county_cvi','state_cvi'])

# %%
df.head(1)
# Out:
#         ALAND    AWATER            NAME    State  fips  LaborForce_01Month  \
# 0  1539602137  25706961  Autauga County  Alabama  1001               25906
#
#    LaborForce_02Month  Employed_01Month  Unemployed_01Month  \
# 0               25912             25196                 710
#
#    PctUnemployed_01Month              CurrentMonth      county_cvi state_cvi  \
# 0                    2.7  March 2020 - Preliminary  Autauga County   Alabama
#
#    vulnerability_index  rank_cvi  objected_cvi  \
# 0               110.31       401           100
#
#                            excel_id_cvi  fips_cvi
# 0  35fc8203-5876-41dc-9977-6cea758857da      1001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3090 entries, 0 to 3089
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ALAND                  3090 non-null   int64
#  1   AWATER                 3090 non-null   int64
#  2   NAME                   3090 non-null   object
#  3   State                  3090 non-null   object
#  4   fips                   3090 non-null   int64
#  5   LaborForce_01Month     3090 non-null   int64
#  6   LaborForce_02Month     3090 non-null   int64
#  7   Employed_01Month       3090 non-null   int64
#  8   Unemployed_01Month     3090 non-null   int64
#  9   PctUnemployed_01Month  3090 non-null   float64
#  10  CurrentMonth           3090 non-null   object
#  11  county_cvi             3090 non-null   object
#  12  state_cvi              3090 non-null   object
#  13  vulnerability_index    3090 non-null   float64
#  14  rank_cvi               3090 non-null   int64
#  15  objected_cvi           3090 non-null   int64
#  16  excel_id_cvi           3090 non-null   object
#  17  fips_cvi               3090 non-null   int64
# dtypes: float64(2), int64(10), object(6)
# memory usage: 458.7+ KB

# %% [markdown]
# we can drop first 3 columns
# ALand: Area of Land
# AWater: Area of Water
# NAME: name of county
# State: name of state
# fips: FIPS code
# LAbourForce_01Month:  Count of people within the US Labor Force - most current month
# Employed_01Month : Count of Employed Population - most current month
# Unemployement_01Month : Count of Unemployed Population - most current month
# PctUnemployement_01Month : Percent Unemployed - most current month
# CurrentMonth :  Month and year - most current month offered by BLS
# county_cvi: county name
# state_name: state name
# vulnerability_index :
# rank_cvi : rank of vulnerability from covid
# objected_cvi: index(we can drop this)
# excel_ID: ed (we can drop this)
# FIPS: FIPS code

# %%
#Check if the merge is successful. Result should be 0
df.query('county_cvi != NAME ')

# %%
df.drop(columns=['fips','LaborForce_02Month','county_cvi','state_cvi','objected_cvi','excel_id_cvi'],axis=1,inplace=True)

# %%
#save the merged file
df.to_csv("cvi_unemployment_2020.csv",index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3090 entries, 0 to 3089
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ALAND                  3090 non-null   int64
#  1   AWATER                 3090 non-null   int64
#  2   NAME                   3090 non-null   object
#  3   State                  3090 non-null   object
#  4   LaborForce_01Month     3090 non-null   int64
#  5   Employed_01Month       3090 non-null   int64
#  6   Unemployed_01Month     3090 non-null   int64
#  7   PctUnemployed_01Month  3090 non-null   float64
#  8   CurrentMonth           3090 non-null   object
#  9   vulnerability_index    3090 non-null   float64
#  10  rank_cvi               3090 non-null   int64
#  11  fips_cvi               3090 non-null   int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 313.8+ KB

# %%
#find the county with maximum land area
df[df.ALAND == max(df.ALAND)]
# Out:
#            ALAND      AWATER                       NAME   State  \
# 94  377038836685  5945279912  Yukon-Koyukuk Census Area  Alaska
#
#     LaborForce_01Month  Employed_01Month  Unemployed_01Month  \
# 94                2394              2054                 340
#
#     PctUnemployed_01Month              CurrentMonth  vulnerability_index  \
# 94                   14.2  March 2020 - Preliminary                44.05
#
#     rank_cvi  fips_cvi
# 94      3056      2290

# %%
#find the county with maximum land area
df[df.AWATER == max(df.AWATER)]
# Out:
#           ALAND       AWATER                        NAME   State  \
# 82  61912947833  25973300388  Lake and Peninsula Borough  Alaska
#
#     LaborForce_01Month  Employed_01Month  Unemployed_01Month  \
# 82                 585               519                  66
#
#     PctUnemployed_01Month              CurrentMonth  vulnerability_index  \
# 82                   11.3  March 2020 - Preliminary               121.35
#
#     rank_cvi  fips_cvi
# 82       225      2164

# %%
#counties with highest labour force
index_top10 = list(df.LaborForce_01Month.sort_values(ascending=False).index[:5])


df.iloc[index_top10]
# Out:
#             ALAND      AWATER                NAME       State  \
# 203   10511861492  1793485467  Los Angeles County  California
# 605    2447357982  1786325586         Cook County    Illinois
# 102   23829622328    63347750     Maricopa County     Arizona
# 2610   4418909573   184757689       Harris County       Texas
# 214    2053367783   401931862       Orange County  California
#
#       LaborForce_01Month  Employed_01Month  Unemployed_01Month  \
# 203              5222823           4984604              238219
# 605              2564954           2476865               88089
# 102              2373098           2283286               89812
# 2610             2361581           2269910               91671
# 214              1623913           1578370               45543
#
#       PctUnemployed_01Month              CurrentMonth  vulnerability_index  \
# 203                     4.6                March 2020               122.14
# 605                     3.4  March 2020 - Preliminary               108.14
# 102                     3.8  March 2020 - Preliminary               103.54
# 2610                    3.9  March 2020 - Preliminary                98.63
# 214                     2.8  March 2020 - Preliminary               110.95
#
#       rank_cvi  fips_cvi
# 203        221      6037
# 605        458     17031
# 102        617      4013
# 2610       857     48201
# 214        389      6059

# %%
#counties with highest unemployment rate 
index_top10_u = list(df.PctUnemployed_01Month.sort_values(ascending=False).index[:5])


df.iloc[index_top10_u]
# Out:
#             ALAND      AWATER                  NAME          State  \
# 89     1123881121    28784118  Skagway Municipality         Alaska
# 190    2980332742    14608887         Colusa County     California
# 2947    723252961     3704011        Calhoun County  West Virginia
# 81    44222017663  6693558019  Kusilvak Census Area         Alaska
# 72    32729577049    66105677        Denali Borough         Alaska
#
#       LaborForce_01Month  Employed_01Month  Unemployed_01Month  \
# 89                   591               466                 125
# 190                11204              8986                2218
# 2947                2756              2215                 541
# 81                  2681              2165                 516
# 72                   561               459                 102
#
#       PctUnemployed_01Month              CurrentMonth  vulnerability_index  \
# 89                     21.2  March 2020 - Preliminary               226.22
# 190                    19.8  March 2020 - Preliminary                81.62
# 2947                   19.6  March 2020 - Preliminary                49.10
# 81                     19.2  March 2020 - Preliminary                43.00
# 72                     18.2  March 2020 - Preliminary               275.00
#
#       rank_cvi  fips_cvi
# 89          12      2230
# 190       1800      6011
# 2947      2994     54013
# 81        3066      2158
# 72           3      2068

# %%
#counties with highest vulnerability index
index_top10_v = list(df.vulnerability_index.sort_values(ascending=False).index[:5])


df.iloc[index_top10_v]
# Out:
#             ALAND    AWATER            NAME           State  \
# 267     388556733    942056   Gilpin County        Colorado
# 2161   1331024899  47506501     Love County        Oklahoma
# 72    32729577049  66105677  Denali Borough          Alaska
# 283    2268209075   5222161  Mineral County        Colorado
# 1964   1366810463  32416167    Swain County  North Carolina
#
#       LaborForce_01Month  Employed_01Month  Unemployed_01Month  \
# 267                 3874              3789                  85
# 2161                6167              6032                 135
# 72                   561               459                 102
# 283                  534               519                  15
# 1964                6729              6407                 322
#
#       PctUnemployed_01Month              CurrentMonth  vulnerability_index  \
# 267                     2.2  March 2020 - Preliminary               348.83
# 2161                    2.2  March 2020 - Preliminary               309.31
# 72                     18.2  March 2020 - Preliminary               275.00
# 283                     2.8  March 2020 - Preliminary               257.30
# 1964                    4.8  March 2020 - Preliminary               250.90
#
#       rank_cvi  fips_cvi
# 267          1      8047
# 2161         2     40085
# 72           3      2068
# 283          4      8079
# 1964         5     37173

# %% [markdown]
# #### An average Vulnerability Index score is 100, representing the average job loss expected in the United States. Higher scores indicate the degree to which job losses may be greater — an index score of 200, for example, means the rate of job loss can be twice as large as the national average. Conversely, an index score of 50 would mean a possible job loss of half the national average. Regions heavily dependent on tourism with relatively high concentrations of leisure and hospitality jobs, for example, are likely to have high index scores.
#
# #### The Vulnerability Index only measures the impact potential related to the mix of industry employment. The index does not take into account variation due to a region’s rate of virus infection, nor does it factor in local government's policies in reaction to the virus.

# %% [markdown]
# # Denali Borough county in Alaska seems to have higest unemployment rate in counties with highest CVI
